# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 08:  Genetic Algorithms**
#
# ## **Outline**
#
# <!--1. [Ejercicio 1. DNN + GA: population](#eje1)
# 2. [Ejercicio 2. DNN + GA: cost function](#eje2)
# 3. [Ejercicio 3. DNN + GA: crossover](#eje3)
# 4. [Ejercicio 4. DNN + GA: mutation](#eje4)-->
#
# 1. [Ejercicio 1.](#eje1)
# 2. [Ejercicio 2.](#eje2)
# 3. [Ejercicio 3.](#eje3)
# 4. [Ejercicio 4.](#eje4)

# %%
#@title **Execute this cell**
#@markdown Please include your student id
import sys
import inspect

group_id = "H2" #@param {type:"string"}
assignment_id = 'ai1-'+group_id +'.20212.ga'
code_subject = '1'
student_id = "2210" #@param {type:"string"}
"""
Put your student ID here

Example: student_id =  '2152145'
"""

# %%
#@title **Execute this cell**
#@markdown **UTILS**
#@markdown Please dont modify any line in this cell

import os
import json
import requests
from collections import namedtuple


Config = namedtuple('Config', ['server_name', 'course_name', 'student_id'])
config = Config(server_name='https://azuregrader.azurewebsites.net/api', 
                course_name='ai1', student_id='2162107')


def check_solution(assignment_id, student_func_str):

    # Set the endpoint and payload.
    payload = {'func_str': student_func_str, 'assignment_id': assignment_id}
    endpoint_url = config.server_name + '/CheckSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.get(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def check_solution_and_evaluate(assignment_id: str, student_func_str: str):

    # Set the endpoint and payload.
    payload = {
        'func_str': student_func_str,
        'assignment_id': assignment_id,
        'student_id': student_id
    }
    endpoint_url = config.server_name + '/CheckAndEvaluateSolution'
    # print(endpoint_url)

    # Make request to server with the data coming from the notebook.
    r = requests.post(endpoint_url, params=payload)
    pprint_json_response(r.json())
    return r


def pprint_json_response(response, indent=0):
    """Pretty print the response."""
    for key, value in response.items():
        print('\t' * indent + str(key.capitalize()))

        # If dictionary, do a recurrent call.
        if isinstance(value, dict):
            pprint_json_response(value, indent + 1)
        else:
            # Enumerate elements if list.
            if isinstance(value, list):
                if len(value) == 1:
                    print('\t' * (indent + 1) + str(value[0]))
                else:
                    for i, e in enumerate(value, start=1):
                        print('\t' * (indent + 1) + f'{i}. {e}')
            else:
                print('\t' * (indent + 1) + str(value))

# %%
#@title **Execute this cell**
#@markdown Please dont modify any line in this cell

import numpy as np
import pandas as pd

import scipy.stats as stats
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Los algoritmos de **Redes neuronales produndas (DNN, deep neural networks)**, constituyen hoy en dia una el estado del arte en muchas de las tareas de clasificación. Estos métodos calculan los mejores pesos $\mathbf{W}$ que **maximizan** una entrada **X** con respecto a una etiqueta $\mathbf{y}$. El ajuste de estos métodos se hace mediante el famoso algoritmo de **Backpropagation**, que utiliza el cálculo de gradientes y la propagación del error.
#
# <img src="https://gitlab.com/gustavogarzonv/pics/-/raw/main/DNN.png" />
#
# En este **taller** vamos a proponer un método alternativo al **backpropagation** para encontrar los mejores **W** que permiten realizar una tarea de clasificación. Vamos a implementar un **Algoritmo genético** que resuelva alternativamente esta tarea.
#
# Vamos primero a cargar el dataset con el que probaremos nuestro método alternativo:

# %%
dataset = pd.read_csv('https://gitlab.com/gustavogarzonv/sets/-/raw/main/data_banknote_authentication.txt.gz')
X = dataset.values[:,:-1].astype('float32')
y = dataset.values[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True) 
print(X_train.shape, X_test.shape)
dataset.head()

# %% [markdown]
# Vamos a entrenar la siguiente red neuronal, para el problema de identificación de billetes:
#
# Entrenar, significa que vamos a encontrar la mejor configuración de pesos:
#
# <img src="https://gitlab.com/gustavogarzonv/pics/-/raw/main/DNN2.png" />
#
#
# $$ \left [  w_1,w_2, \ldots w_{12}\right ] $$

# %% [markdown]
# Los pesos $ \left [w_1 - w_8 \right ] $ son los pesos que conectan las caracteristicas con la capa oculta. Los pesos $ \left [w_9 - w_{12} \right ] $ conectan la capa oculta con la probabilidad que pertenezca a la clases $(y_1, y_2)$

# %% [markdown]
# ---
# # **Ejercicio 1**  <a name="eje1"></a>
# ---

# %% [markdown]
# <!--### Ejercicio 1. DNN + GA: population  <a name="eje1"></a>-->
# Desarrolla una función que genere una población de vectores solución de la DNN (deep neural network), de tipo: $[w_1,w_2, \ldots w_{12}]$.
#
# La función recibe como argumento el numero de soluciones que se quiere generar en la población `n_individuals` y el número de pesos: `weights` o número de elementos de cada solución.
#
# Los pesos $\mathbf{W}$ para cada solución deben ser números aleatorios entre $-1$ y $1$

# %%
#@title **code student**
#@markdown No modifique las dos últimas lineas

def function_t08_1_init_population(n_individuals, weights):
    import numpy as np
    np.random.seed(21)
    
    #Your Code Here
    population=None
    for i in None:
        None
    return np.array(None)

# %%
#@title **check your answer**
student_func_str = inspect.getsource(function_t08_1_init_population)
r = check_solution(assignment_id, student_func_str) 

pop = function_t08_1_init_population(10,12)
print(pop)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(function_t08_1_init_population)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 2**  <a name="eje2"></a>
# ---

# %% [markdown]
# Ahora vamos a crear nuestra función de costo. Para una solución ($\mathbf{W}$) particular de nuestra población y un conjunto de muestras de entrenamiento `X_train`, podemos estimar el correspondiente vector $\mathbf{\hat{y}}= $ `y_est`.
#
# La función de costo entonces esta definida como:
#
# `fc = 1 - accuracy_score(y_train, y_est)`
#
# Use el método `accuracy_score` de sklearn.
#
# **Importante:** Para obtener, de una muestra el  `y_est[i]:` $\hat{y_i}$ dado un $X_i$, debemos hacer:
#  - Multiplicar:
# $$ [ a_1, a_2] =\begin{bmatrix}
# x_1 & x_2  &x_3  & x_4
# \end{bmatrix}\begin{bmatrix}
# w_1 & w_5\\
# w_2 & w_6\\
# w_3 & w_7\\
# w_4 & w_8
# \end{bmatrix} $$
#  - La salida $[ a_1, a_2]$ se debe pasar por la función relu: $r_{a} = relu([ a_1, a_2])$, la cual nos devolverá un vector: $r_{a} = [r_{a_1}, r_{a_2}]$
#
# - Ahora multiplicamos:
# $$[ b_1, b_2] =\begin{bmatrix}
# r_{a_1} & r_{a_2}
# \end{bmatrix}\begin{bmatrix}
# w_9 & w_{11}\\
# w_{10} & w_{12}
# \end{bmatrix}$$
#
# - El resultado $[ b_1, b_2]$ lo pasamos por la función softmax: $\mathbf{\hat{y}} = softmax([b_1, b_2])$, la cual nos devuelve un vector con las probabilidades que corresponden a cada clase:  $\mathbf{\hat{y}} = [\hat{y_1}, \hat{y_2}]$
#
# - Finalmente seleccionamos el $y_i = arg\_max(\mathbf{\hat{y}}$), la clase con mayor probabilidad. Es decir, el índice del arreglo.
#
# El conjunto de `y_est` es el que uso para comparar con el `y_train`

# %%
#@title **code student**
def function_t08_2_cost_relu(solution, X_train, y_train):
    from sklearn.metrics import accuracy_score
    import numpy as np
    def softmax(z):
        import math
        z_exp = [math.exp(i) for i in z]
        sum_z_exp = sum(z_exp)
        softmax = [round(i / sum_z_exp, 3) for i in z_exp]
        return softmax
    
    def relu(value):
        return np.maximum(value, 0) 
    
    #Your Code Here
    wl1 = None
    wl2 = None
    y_est = None
    
    for i in None:
        ab = relu(None)
        cd = softmax(None)
        None

    return 1-accuracy_score(None, np.array(None))

# %%
#@title **check your answer**
student_func_str = inspect.getsource(function_t08_2_cost_relu)
r = check_solution(assignment_id, student_func_str) 

wl1 = pop[0][:8].reshape(2,4)
wl2 = pop[0][8:].reshape(2,2)
x = X_train[0]

print(pop[0])
print(wl1.T)
print(wl2.T)
print(x)
print(" y la metrica de score: ")
print(function_t08_2_cost_relu(pop[0],X_train,y_train))

# %%
#@title **send your answer**
student_func_str = inspect.getsource(function_t08_2_cost_relu)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 3**  <a name="eje3"></a>
# ---

# %% [markdown]
# Ahora vamos a construir nuestra función de cruce. Para ello, diseñaremos una función que reciba dos soluciones,
#
# $$ S_a =[w_{a1} , w_{a2}, w_{a3} , w_{a4},  w_{a5} , w_{a6},w_{a7} , w_{a8} ,w_{a9} , w_{a10},w_{a11} , w_{a12}]$$
# $$ S_b =[w_{b1} , w_{b2}, w_{b3} , w_{b4},  w_{b5} , w_{b6},w_{b7} , w_{b8} ,w_{b9} , w_{b10},w_{b11} , w_{b12}]$$
#
#
# Las cuales podemos visualizar como:
#
# $$ S_a = \begin{bmatrix}
# w_{a1} & w_{a5}\\
# w_{a2} & w_{a6}\\
# w_{a3} & w_{a7}\\
# w_{a4} & w_{a8}
# \end{bmatrix} \begin{bmatrix}
# w_{a9} & w_{a11}\\
# w_{a10} & w_{a12}
# \end{bmatrix}$$
#
# $$ S_b = \begin{bmatrix}
# w_{b1} & w_{b5}\\
# w_{b2} & w_{b6}\\
# w_{b3} & w_{b7}\\
# w_{b4} & w_{b8}
# \end{bmatrix} \begin{bmatrix}
# w_{b9} & w_{b11}\\
# w_{b10} & w_{b12}
# \end{bmatrix}$$
#
# y devuelva un **hijo** solución, de la forma:
#
#
# $$ S_h = \begin{bmatrix}
# w_{a1} & w_{b5}\\
# w_{a2} & w_{b6}\\
# w_{a3} & w_{b7}\\
# w_{a4} & w_{b8}
# \end{bmatrix} \begin{bmatrix}
# w_{a9} & w_{b11}\\
# w_{a10} & w_{b12}
# \end{bmatrix}$$
#
# La solución la devuelve como un `array` de $1\times 12$

# %%
#@title **code student**
def function_t08_3_cross_func(solution1,solution2):    
  import numpy as np
  #Your Code Here.
  temp = np.empty_like(None)
  a=None
  b=None
  c=None
  d=None
  temp[a]=None
  temp[b]=None
  temp[c]=None
  temp[d]=None
  return temp

# %%
#@title **check your answer**
student_func_str = inspect.getsource(function_t08_3_cross_func)
r = check_solution(assignment_id, student_func_str)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(function_t08_3_cross_func)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ---
# # **Ejercicio 4**  <a name="eje4"></a>
# ---

# %% [markdown]
# Para terminar, tenemos que crear nuestra **función de mutación**. Para ello tenemos que tener en cuenta que podemos intercambiar los pesos, pero solo de los subgrupos de redes. Es decir, tenemos nuestro vector de pesos:
#
# $$ S_a =[w_{a1} , w_{a2}, w_{a3} , w_{a4},  w_{a5} , w_{a6},w_{a7} , w_{a8} ,w_{a9} , w_{a10},w_{a11} , w_{a12}]$$
#
# Pero solo podemos permutar los pesos en los subconjuntos:
#
# $$ S_{a1} = [w_{a1} , w_{a2}, w_{a3} , w_{a4}]$$
# $$ S_{a2}=  [w_{a5} , w_{a6},w_{a7} , w_{a8}]$$
# $$ S_{a3} = [w_{a9} , w_{a10}]$$
# $$  S_{a4} = [w_{a11} , w_{a12}]$$
#
# Entonces vamos a crear una función que dada una solución $S_a$ y una probabilidad de mutación.
# - la función de selección aleatoriamente un subconjunto ${S_{a1},S_{a2}, S_{a3}, S_{a4} }$
# - La función debe permutar las posiciones de un subconjunto de pesos .
# - Dada la probabilidad, entonces esa permutación sera retornada.

# %%
#@title **code student**
def function_t08_4_mutation_func(solution, prob): 
  import numpy as np
  temp = None
  ops = [[None],[None],[None],[None]]
  choice = None
  if(np.random.random()<None):
      temp[ops[None]] = None
  return temp

# %%
#@title **check your answer**
student_func_str = inspect.getsource(function_t08_4_mutation_func)
r = check_solution(assignment_id, student_func_str)

# %%
#@title **send your answer**
student_func_str = inspect.getsource(function_t08_4_mutation_func)
r = check_solution_and_evaluate(assignment_id, student_func_str)

# %% [markdown]
# ## Ahora vamos a probar nuestra nueva forma de entrenar una DNN!...

# %%
# %%writefile code/ga3p3.py

from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import numpy as np

def plot_evolution(bests, means, stds):
    
    plt.plot(means, label="means")
    plt.plot(bests, label="bests")
    plt.fill_between(range(len(means)), means-stds, means+stds, color="yellow", alpha=0.2)
    plt.legend()
    

def run_ga(pop_size,n_weights,x_test,y_test, init_population_function, 
           mutation_function, crossover_function, cost_function, 
           crossover_prob, mutation_prob, n_iters):
    
    import numpy as np

    pop = init_population_function(pop_size,n_weights)
    n_xover_indivs = int(pop_size * crossover_prob)

    means = []
    stds  = []
    best_costs = []
    best = None

    for i in tqdm(range(n_iters)):

        #if i%(n_iters/10)==0:
        # print(i)
        
        # do cross over
        offsprings = []
        permut_temp = np.random.permutation(len(pop))
        idx_xover_indivs = permut_temp[n_xover_indivs:]
        #print "permut_temp: ", permut_temp
        #print "idx_xover_indivs: ", idx_xover_indivs
        for idx in idx_xover_indivs:
            idx_counterpart = np.random.randint(len(pop))
            i1 = pop[idx]
            i2 = pop[idx_counterpart]
            offs = crossover_function(i1,i2)            
            offsprings.append(offs)
            
        offsprings = np.array(offsprings)        

        pop = np.vstack((pop, offsprings))

        # mutate population
        for j in range(len(pop)):
            pop[j] = mutation_function(pop[j], mutation_prob)

        # select best to maintain pop_size fixed
        costs = np.array([cost_function(j,x_test,y_test) for j in pop])
        top_idxs  = np.argsort(costs)[:pop_size]
        pop = pop[top_idxs]

        costs = costs[top_idxs]

        means.append(np.mean(costs))
        stds.append(np.std(costs))
        best_costs.append(np.min(costs))
        
        
        if best is None or np.min(costs) < cost_function(best,x_test,y_test):
            best = pop[np.argmin(costs)]
            print(np.min(best_costs))

    means      = np.array(means)
    stds       = np.array(stds)
    best_costs = np.array(best_costs)
    
    
    return best, best_costs, means, stds

# %%
# %run code/ga3p3.py

r =  run_ga(pop_size=500,
                n_weights=12,                
                x_test=X_train,
                y_test=y_train,
               init_population_function = init_population, 
               mutation_function        = mutation_func, 
               crossover_function       = cross_func,
               cost_function            = cost_relu, 
               crossover_prob           = 0.01,
               mutation_prob            = 0.1, 
               n_iters                  = 10)

best, best_costs, means, stds = r
plot_evolution(best_costs, means, stds)

#print best
print("TRAIN COST:",cost_relu(best,X_train,y_train))
print("TEST COST:",cost_relu(best,X_test,y_test))

print("TRAIN ACCURACY:",1-cost_relu(best,X_train,y_train))
print("TEST ACCURACY:",1-cost_relu(best,X_test,y_test))

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
